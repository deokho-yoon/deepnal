# %%
# %run ../chap06/adam_model.ipynb
# %run ../chap06/dataset_office31.ipynb

# %%
od = Office31Dataset()

# %%
om1 = AdamModel('office31_model_1', od, [10])
om1.exec_all(epoch_count=20, report=10)
# Out:
# Model office31_model_1 train started:
#     Epoch 10: cost=4.299, accuracy=0.682+0.040/0.740+0.050 (11/11 secs)
#     Epoch 20: cost=4.271, accuracy=0.682+0.040/0.750+0.040 (12/23 secs)
# Model office31_model_1 train ended in 23 secs:
# Model office31_model_1 test report: accuracy = 0.685+0.042, (0 secs)
#
# Model office31_model_1 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [20,65,15] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [20,65,15] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [20,65,15] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 speaker => X
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 bike => X
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 scissors => X

# %%
om2 = AdamModel('office31_model_2', od, [64,32,10])
om2.exec_all(epoch_count=50, report=10, learning_rate=0.0001)
# Out:
# Model office31_model_2 train started:
#     Epoch 10: cost=3.737, accuracy=0.798+0.074/0.880+0.120 (63/63 secs)
#     Epoch 20: cost=3.467, accuracy=0.828+0.124/0.890+0.140 (65/128 secs)
#     Epoch 30: cost=3.327, accuracy=0.838+0.155/0.890+0.170 (63/191 secs)
#     Epoch 40: cost=3.223, accuracy=0.846+0.173/0.850+0.230 (69/260 secs)
#     Epoch 50: cost=3.129, accuracy=0.850+0.191/0.910+0.160 (63/323 secs)
# Model office31_model_2 train ended in 323 secs:
# Model office31_model_2 test report: accuracy = 0.806+0.192, (0 secs)
#
# Model office31_model_2 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [ 5,93, 3] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [ 0,100, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [ 2,96, 2] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 4, 3, 3, 2, 1, 3, 4, 4,...] => 추정 mug : 정답 bike_helmet => X
# 추정확률분포 [ 1, 1, 1, 2,57, 3, 1, 1,...] => 추정 back_pack : 정답 back_pack => O
# 추정확률분포 [ 2,11, 2, 8, 3, 2, 9, 5,...] => 추정 laptop_computer : 정답 speaker => X

# %%
om3 = AdamModel('office31_model_3', od, [64,32,10])
om2.use_adam = True
om3.exec_all(epoch_count=50, report=10, learning_rate=0.0001)
# Out:
# Model office31_model_3 train started:
#     Epoch 10: cost=3.667, accuracy=0.794+0.108/0.960+0.090 (64/64 secs)
#     Epoch 20: cost=3.353, accuracy=0.831+0.166/0.910+0.160 (63/127 secs)
#     Epoch 30: cost=3.182, accuracy=0.850+0.199/0.870+0.190 (63/190 secs)
#     Epoch 40: cost=3.051, accuracy=0.864+0.227/0.880+0.180 (65/255 secs)
#     Epoch 50: cost=2.899, accuracy=0.879+0.266/0.900+0.210 (62/317 secs)
# Model office31_model_3 train ended in 317 secs:
# Model office31_model_3 test report: accuracy = 0.856+0.229, (0 secs)
#
# Model office31_model_3 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [ 0,100, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [ 0,100, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [86, 0,14] => 추정 webcam : 정답 webcam => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 1, 1, 0, 4, 0, 2, 2, 1,...] => 추정 phone : 정답 punchers => X
# 추정확률분포 [ 2, 3, 1, 2, 9, 2, 6, 0,...] => 추정 paper_notebook : 정답 tape_dispenser => X
# 추정확률분포 [ 3, 4, 1, 6, 0, 1, 1,10,...] => 추정 speaker : 정답 speaker => O
